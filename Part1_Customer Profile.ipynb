# %%
import time
import tweepy
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
# %run ./keys.ipynb

# %%
callback_uri = 'oob'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
auth.set_access_token(access_token,access_token_secret)

# %%
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
tweets = []
users = []
    
geo='-33.865143,151.209900,50km' # geocode for sydney with 50km radius

# keyword filters to categorise consumers' interests

kw_cleaning = 'cleaning OR household OR disinfectant' # cleaning products
kw_food = 'food OR cooking OR chef OR homemade food' # fresh food and cooking
kw_beauty = 'makeup OR lipstick OR concealer OR foundation OR blush OR mascara' # beauty products
kw_school = 'stationary OR student OR school OR notebooks OR exercise books OR primary' # back to school products

# %%
# example: users interested in food items
for tweet in tweepy.Cursor(api.search, q=kw_food, geocode=geo).items(100):
    tweets.append(tweet.text)
    users.append(tweet.user.screen_name) # an array of users who are interested in food items

# %%
df = pd.DataFrame({'Tweet':tweets,'User':users})
df.head(100)
# Out:
#                                                 Tweet             User
# 0   @colonelblimp2 Yes it’s run out of each state/...     elle_desylva
# 1   Nick Kyrgios said he had a slow start yesterda...        LMcKirdy7
# 2   Congrats Karen @WaffleHouse in Biloxi. U got a...    paycompliment
# 3   Northeast Ohio Ice Cream Guide: unique spots o...       NHillsNews
# 4   RT @HannahD15: Menulog's trial of actually *em...          DamirDM
# ..                                                ...              ...
# 95  RT @IMAROOSTAR: If you know any pensioners bet...   PameStinEllada
# 96  RT @jackiemsydney: The sweet lowdown on the su...     Net2Ayurveda
# 97  RT @jackiemsydney: Our latest eMag is being se...     Net2Ayurveda
# 98  @AngriestTiger @NSWBlues @WestsTigers @TOwolfp...  TheBiggestTiger
# 99  RT @TheBiggestTiger: Half expected to see @Von...         beges007
#
# [100 rows x 2 columns]

# %%
j = 1
for i in range (0, 100):
       print(str(j)+')' + df['User'][i])
       j = j + 1
# Out:
# 1)elle_desylva
# 2)LMcKirdy7
# 3)paycompliment
# 4)NHillsNews
# 5)DamirDM
# 6)Philip19600630
# 7)feedingmyfamily
# 8)wavydoppio
# 9)kymmidd
# 10)LouieLouLouigi
# 11)JackieHansard
# 12)skgri_x2
# 13)natalieheding
# 14)svftchloe
# 15)mrn487
# 16)baconised
# 17)arisadraconis
# 18)JohannaSzabo1
# 19)3catsfoodie
# 20)Buuloki
# 21)SENMlTSU
# 22)esseeeayeenn
# 23)Tim_Coronel
# 24)coybowbaby
# 25)cscviews
# 26)janinesymons
# 27)kensultancy325
# 28)kayorchison
# 29)JakeChatty
# 30)redrosetta789
# 31)ConnorLiz
# 32)AManTalksNrlSC
# 33)AuthorGrover
# 34)pikalew
# 35)AngelEze07
# 36)alextalamo_
# 37)dude_brick
# 38)sydnets
# 39)queerhow
# 40)CircleDaydreams
# 41)wheeziemungo
# 42)solopassport
# 43)AungKyawMinn2
# 44)4orty6ix
# 45)aus99a
# 46)NutritionAusNSW
# 47)woodedhollow
# 48)EduardoSpectro1
# 49)Julaberry
# 50)sunny_nix
# 51)Afoodaficionado
# 52)FusionProgGuy
# 53)bigbiteeco
# 54)Kirrily
# 55)Kirrily
# 56)msjingold
# 57)elliotjayoneill
# 58)FusionProgGuy
# 59)Likay
# 60)tomdcc
# ...
